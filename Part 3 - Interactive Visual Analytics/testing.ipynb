# %%
import pandas as pd
import plotly.express as px
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df
# Out:
#     Launch Site  Unnamed: 0  Flight Number  class  Payload Mass (kg)  \
# 0   CCAFS LC-40           0              1      0                0.0
# 1  CCAFS SLC-40          49             45      1             2205.0
# 2    KSC LC-39A          36             30      1             2490.0
# 3   VAFB SLC-4E          26              6      0              500.0
#
#   Booster Version Booster Version Category
# 0  F9 v1.0  B0003                     v1.0
# 1  F9 FT  B1035.2                       FT
# 2   F9 FT B1031.1                       FT
# 3  F9 v1.1  B1003                     v1.1

# %%
options = [{ 'label': 'All Sites', 'value': 'All'}] +  [{'label' : site, 'value': site}for site in launch_sites_df['Launch Site']]
options
# Out:
# [{'label': 'All Sites', 'value': 'All'},
#  {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
#  {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
#  {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
#  {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}]

# %%
spacex_df['label class'] = spacex_df['class'].map({0: 'Failed', 1: 'Success'})
spacex_df

# %%
px.pie(data_frame=spacex_df, names='Launch Site', values='class', title='Success Rate of All sites')

# %%
px.pie(data_frame=spacex_df[spacex_df['Launch Site'] == 'CCAFS LC-40'], names='label class')

# %%
fig = px.scatter(data_frame=spacex_df, x='Payload Mass (kg)', y='class', color='Booster Version Category', title='Correlation between Payload Mass and Success for all sites')
fig.update_yaxes(
    tickvals=[0, 1],
    ticktext=['Failed', 'Success']
)

# %%
slider = [100, 9000]
site = 'KSC LC-39A'

fig = px.scatter(data_frame=spacex_df, x='Payload Mass (kg)', y='class', color='Booster Version Category', title='Correlation between Payload Mass and Success for all sites')
fig.update_yaxes(
    tickvals=[0, 1],
    ticktext=['Failed', 'Success']
)
